# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("handle_Attack_data/TOTAL_handle8.csv",encoding='UTF-8')
x, y = data.iloc[:, :-1].values, data.iloc[:, -1].values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)
feat_labels = data.columns[1:]
forest = RandomForestClassifier(n_estimators=10000, random_state=0, n_jobs=-1)
forest.fit(x_train, y_train)
print("kkkkkkkkkkkk")
#data = pd.read_csv("C:/research/research/IOT/MLIDS/test/testhandle.csv",header=None)

# x = data.iloc[:,:-1]
# y = data.iloc[:,-1]
#
# RF = RandomForestClassifier(random_state=0, n_jobs=-1)
# RFmodel=RF.fit(x,y)
importances = forest.feature_importances_
indices = np.argsort(importances)[::-1]
for f in range(x_train.shape[1]):
    print("%2d) %-*s %f" % (f + 1, 30, feat_labels[indices[f]], importances[indices[f]]))
# Out:
# kkkkkkkkkkkk
#  1)  Flow Duration                 0.042167
#  2)  Total Length of Bwd Packets   0.036113
#  3)  Subflow Bwd Packets           0.034295
#  4)  Min Packet Length             0.033889
#  5)  Init_Win_bytes_backward       0.032312
#  6)  Fwd Packet Length Min         0.031981
#  7)  Avg Fwd Segment Size          0.031674
#  8)  Packet Length Std             0.029547
#  9)  Avg Bwd Segment Size          0.028864
# 10)  Fwd IAT Min                   0.028558
# 11)  Fwd Packet Length Std         0.028532
# 12)  Total Backward Packets        0.025985
# 13)  Subflow Fwd Bytes             0.025117
# 14) Init_Win_bytes_forward         0.023487
# 15)  Fwd Header Length.1           0.023152
# 16)  Fwd Packet Length Max         0.023100
# 17)  Bwd Packet Length Std         0.022986
# 18)  Bwd Packet Length Mean        0.021722
# 19)  Fwd IAT Mean                  0.021648
# 20)  Flow IAT Min                  0.021439
# 21)  Fwd IAT Std                   0.021230
# 22)  Packet Length Variance        0.020837
# 23)  act_data_pkt_fwd              0.019378
# 24)  ACK Flag Count                0.018507
# 25)  Label                         0.018458
# 26) FIN Flag Count                 0.018416
# 27) Flow Bytes/s                   0.017935
# 28) Subflow Fwd Packets            0.017860
# 29)  Idle Std                      0.017028
# 30)  Bwd Header Length             0.016952
# 31)  Packet Length Mean            0.015531
# 32)  Flow Packets/s                0.015397
# 33)  min_seg_size_forward          0.015020
# 34)  Bwd Packet Length Min         0.014942
# 35)  Fwd IAT Max                   0.014734
# 36)  Idle Min                      0.013085
# 37)  Flow IAT Max                  0.012948
# 38) Fwd Packets/s                  0.012375
# 39)  Max Packet Length             0.012006
# 40) Bwd Packet Length Max          0.010987
# 41)  Total Fwd Packets             0.010960
# 42)  Bwd Packets/s                 0.009696
# 43)  Flow IAT Mean                 0.008770
# 44)  Flow IAT Std                  0.008479
# 45)  Fwd Packet Length Mean        0.008302
# 46) Bwd IAT Total                  0.008204
# 47) Active Mean                    0.007822
# 48)  URG Flag Count                0.005893
# 49)  Subflow Bwd Bytes             0.005578
# 50) Total Length of Fwd Packets    0.005301
# 51) Fwd IAT Total                  0.004918
# 52)  Bwd IAT Mean                  0.003291
# 53)  Bwd IAT Min                   0.002850
# 54)  Bwd IAT Std                   0.002651
# 55)  Bwd IAT Max                   0.002461
# 56) Fwd PSH Flags                  0.001943
# 57)  CWE Flag Count                0.001918
# 58) Idle Mean                      0.001830
# 59)  Active Std                    0.001666
# 60)  Active Min                    0.001478
# 61)  Average Packet Size           0.001363
# 62)  SYN Flag Count                0.001270
# 63)  RST Flag Count                0.001015
# 64)  Fwd URG Flags                 0.000950
# 65)  Idle Max                      0.000881
# 66)  Active Max                    0.000308
# 67)  Fwd Header Length             0.000003
# 68)  ECE Flag Count                0.000003
# 69)  Down/Up Ratio                 0.000000
# 70)  PSH Flag Count                0.000000

# %%
get_ipython().run_line_magic('matplotlib', 'notebook')


plt.title("feature_importances")
plt.bar(range(x_train.shape[1]),
        importances[indices],
        color='lightblue',
        align='center')
plt.xticks(range(x_train.shape[1]),
           feat_labels,rotation=90)
plt.xlim([-1,x_train.shape[1]])
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="928.5333333333333">
